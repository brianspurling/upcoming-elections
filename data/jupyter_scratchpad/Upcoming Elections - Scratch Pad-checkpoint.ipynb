# %%
import requests
import pandas as pd
import csv
import json
from pprint import pprint as print


from uk_election_ids.election_ids import IdBuilder

# %%
# ELECTION TYPES
url_et = 'http://elections.democracyclub.org.uk/api/election_types/'
r_et = requests.get(url_et)
data_et = r_et.json()

electionTypes = {}

for electionTypeDict in data_et['results']:
    electionTypes[electionTypeDict['election_type']] = electionTypeDict['name']

# %%
# ELECTION SUBTYPES
url_est = 'http://elections.democracyclub.org.uk/api/election_subtypes/'
r_est = requests.get(url_est)
data_est = r_est.json()
df_est = pd.DataFrame(data_est['results'])

# %%
# ORGANISATIONS
url_o = 'https://elections.democracyclub.org.uk/api/organisations'
organisations = {}

while url_o:
    r_o = requests.get(url_o)
    data_o = r_o.json()
    for orgDict in data_o['results']:
        organisations[orgDict['slug']] = orgDict
    url_o = data_o['next']

# %%
print(organisations)
# Out:
# {'aberdeen-city': {'common_name': 'Aberdeen City',
#                    'election_name': 'Aberdeen City local election',
#                    'end_date': None,
#                    'official_identifier': 'ABE',
#                    'official_name': 'The Aberdeen City Council',
#                    'organisation_subtype': 'CA',
#                    'organisation_type': 'local-authority',
#                    'slug': 'aberdeen-city',
#                    'start_date': '1996-04-01',
#                    'territory_code': 'SCT',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ABE/1996-04-01/'},
#  'aberdeenshire': {'common_name': 'Aberdeenshire',
#                    'election_name': 'Aberdeenshire local election',
#                    'end_date': None,
#                    'official_identifier': 'ABD',
#                    'official_name': 'The Aberdeenshire Council',
#                    'organisation_subtype': 'CA',
#                    'organisation_type': 'local-authority',
#                    'slug': 'aberdeenshire',
#                    'start_date': '1996-04-01',
#                    'territory_code': 'SCT',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ABD/1996-04-01/'},
#  'adur': {'common_name': 'Adur',
#           'election_name': 'Adur local election',
#           'end_date': None,
#           'official_identifier': 'ADU',
#           'official_name': 'Adur District Council',
#           'organisation_subtype': 'NMD',
#           'organisation_type': 'local-authority',
#           'slug': 'adur',
#           'start_date': '1974-04-01',
#           'territory_code': 'ENG',
#           'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ADU/1974-04-01/'},
#  'allerdale': {'common_name': 'Allerdale',
#                'election_name': 'Allerdale local election',
#                'end_date': None,
#                'official_identifier': 'ALL',
#                'official_name': 'Allerdale Borough Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'allerdale',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ALL/1974-04-01/'},
#  'amber-valley': {'common_name': 'Amber Valley',
#                   'election_name': 'Amber Valley local election',
#                   'end_date': None,
#                   'official_identifier': 'AMB',
#                   'official_name': 'Amber Valley Borough Council',
#                   'organisation_subtype': 'NMD',
#                   'organisation_type': 'local-authority',
#                   'slug': 'amber-valley',
#                   'start_date': '1974-04-01',
#                   'territory_code': 'ENG',
#                   'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/AMB/1974-04-01/'},
#  'angus': {'common_name': 'Angus',
#            'election_name': 'Angus local election',
#            'end_date': None,
#            'official_identifier': 'ANS',
#            'official_name': 'The Angus Council',
#            'organisation_subtype': 'CA',
#            'organisation_type': 'local-authority',
#            'slug': 'angus',
#            'start_date': '1996-04-01',
#            'territory_code': 'SCT',
#            'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ANS/1996-04-01/'},
#  'antrim-and-newtownabbey': {'common_name': 'Antrim and Newtownabbey',
#                              'election_name': 'Antrim and Newtownabbey local '
#                                               'election',
#                              'end_date': None,
#                              'official_identifier': 'ANN',
#                              'official_name': 'Antrim and Newtownabbey Borough '
#                                               'Council',
#                              'organisation_subtype': '',
#                              'organisation_type': 'local-authority',
#                              'slug': 'antrim-and-newtownabbey',
#                              'start_date': '2015-04-01',
#                              'territory_code': 'NIR',
#                              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ANN/2015-04-01/'},
#  'ards-and-north-down': {'common_name': 'Ards and North Down',
#                          'election_name': 'Ards and North Down local election',
#                          'end_date': None,
#                          'official_identifier': 'AND',
#                          'official_name': 'Ards and North Down Borough Council',
#                          'organisation_subtype': '',
#                          'organisation_type': 'local-authority',
#                          'slug': 'ards-and-north-down',
#                          'start_date': '2015-04-01',
#                          'territory_code': 'NIR',
#                          'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/AND/2015-04-01/'},
#  'argyll-and-bute': {'common_name': 'Argyll and Bute',
#                      'election_name': 'Argyll and Bute local election',
#                      'end_date': None,
#                      'official_identifier': 'AGB',
#                      'official_name': 'The Argyll and Bute Council',
#                      'organisation_subtype': 'CA',
#                      'organisation_type': 'local-authority',
#                      'slug': 'argyll-and-bute',
#                      'start_date': '1996-04-01',
#                      'territory_code': 'SCT',
#                      'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/AGB/1996-04-01/'},
#  'armagh-city-banbridge-and-craigavon': {'common_name': 'Armagh City, '
#                                                         'Banbridge and '
#                                                         'Craigavon',
#                                          'election_name': 'Armagh City, '
#                                                           'Banbridge and '
#                                                           'Craigavon local '
#                                                           'election',
#                                          'end_date': None,
#                                          'official_identifier': 'ABC',
#                                          'official_name': 'Armagh City, '
#                                                           'Banbridge and '
#                                                           'Craigavon Borough '
#                                                           'Council',
#                                          'organisation_subtype': '',
#                                          'organisation_type': 'local-authority',
#                                          'slug': 'armagh-city-banbridge-and-craigavon',
#                                          'start_date': '2015-04-01',
#                                          'territory_code': 'NIR',
#                                          'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ABC/2015-04-01/'},
#  'arun': {'common_name': 'Arun',
#           'election_name': 'Arun local election',
#           'end_date': None,
#           'official_identifier': 'ARU',
#           'official_name': 'Arun District Council',
#           'organisation_subtype': 'NMD',
#           'organisation_type': 'local-authority',
#           'slug': 'arun',
#           'start_date': '1974-04-01',
#           'territory_code': 'ENG',
#           'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ARU/1974-04-01/'},
#  'ashfield': {'common_name': 'Ashfield',
#               'election_name': 'Ashfield local election',
#               'end_date': None,
#               'official_identifier': 'ASH',
#               'official_name': 'Ashfield District Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'ashfield',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ASH/1974-04-01/'},
#  'ashford': {'common_name': 'Ashford',
#              'election_name': 'Ashford local election',
#              'end_date': None,
#              'official_identifier': 'ASF',
#              'official_name': 'Ashford Borough Council',
#              'organisation_subtype': 'NMD',
#              'organisation_type': 'local-authority',
#              'slug': 'ashford',
#              'start_date': '1974-04-01',
#              'territory_code': 'ENG',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/ASF/1974-04-01/'},
#  'avon-and-somerset': {'common_name': 'Avon and Somerset Constabulary',
#                        'election_name': 'Police and Crime Commissioner for '
#                                         'Avon and Somerset Constabulary',
#                        'end_date': None,
#                        'official_identifier': 'avon-and-somerset',
#                        'official_name': 'Avon and Somerset Constabulary',
#                        'organisation_subtype': '',
#                        'organisation_type': 'police-area',
#                        'slug': 'avon-and-somerset',
#                        'start_date': '2012-11-15',
#                        'territory_code': 'ENG',
#                        'url': 'http://elections.democracyclub.org.uk/api/organisations/police-area/avon-and-somerset/2012-11-15/'},
#  'aylesbury-vale': {'common_name': 'Aylesbury Vale',
#                     'election_name': 'Aylesbury Vale local election',
#                     'end_date': None,
#                     'official_identifier': 'AYL',
#                     'official_name': 'Aylesbury Vale District Council',
#                     'organisation_subtype': 'NMD',
#                     'organisation_type': 'local-authority',
#                     'slug': 'aylesbury-vale',
#                     'start_date': '1974-04-01',
#                     'territory_code': 'ENG',
#                     'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/AYL/1974-04-01/'},
#  'babergh': {'common_name': 'Babergh',
#              'election_name': 'Babergh local election',
#              'end_date': None,
#              'official_identifier': 'BAB',
#              'official_name': 'Babergh District Council',
#              'organisation_subtype': 'NMD',
#              'organisation_type': 'local-authority',
#              'slug': 'babergh',
#              'start_date': '1974-04-01',
#              'territory_code': 'ENG',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BAB/1974-04-01/'},
#  'barking-and-dagenham': {'common_name': 'Barking and Dagenham',
#                           'election_name': 'Barking and Dagenham local '
#                                            'election',
#                           'end_date': None,
#                           'official_identifier': 'BDG',
#                           'official_name': 'London Borough of Barking and '
#                                            'Dagenham',
#                           'organisation_subtype': 'LBO',
#                           'organisation_type': 'local-authority',
#                           'slug': 'barking-and-dagenham',
#                           'start_date': '1965-04-01',
#                           'territory_code': 'ENG',
#                           'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BDG/1965-04-01/'},
#  'barnet': {'common_name': 'Barnet',
#             'election_name': 'Barnet local election',
#             'end_date': None,
#             'official_identifier': 'BNE',
#             'official_name': 'London Borough of Barnet',
#             'organisation_subtype': 'LBO',
#             'organisation_type': 'local-authority',
#             'slug': 'barnet',
#             'start_date': '1965-04-01',
#             'territory_code': 'ENG',
#             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BNE/1965-04-01/'},
#  'barnsley': {'common_name': 'Barnsley',
#               'election_name': 'Barnsley local election',
#               'end_date': None,
#               'official_identifier': 'BNS',
#               'official_name': 'Barnsley Metropolitan Borough Council',
#               'organisation_subtype': 'MD',
#               'organisation_type': 'local-authority',
#               'slug': 'barnsley',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BNS/1974-04-01/'},
#  'barrow-in-furness': {'common_name': 'Barrow-in-Furness',
#                        'election_name': 'Barrow-in-Furness local election',
#                        'end_date': None,
#                        'official_identifier': 'BAR',
#                        'official_name': 'Barrow-in-Furness Borough Council',
#                        'organisation_subtype': 'NMD',
#                        'organisation_type': 'local-authority',
#                        'slug': 'barrow-in-furness',
#                        'start_date': '1974-04-01',
#                        'territory_code': 'ENG',
#                        'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BAR/1974-04-01/'},
#  'basildon': {'common_name': 'Basildon',
#               'election_name': 'Basildon local election',
#               'end_date': None,
#               'official_identifier': 'BAI',
#               'official_name': 'Basildon Borough Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'basildon',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BAI/1974-04-01/'},
#  'basingstoke-and-deane': {'common_name': 'Basingstoke and Deane',
#                            'election_name': 'Basingstoke and Deane local '
#                                             'election',
#                            'end_date': None,
#                            'official_identifier': 'BAN',
#                            'official_name': 'Basingstoke and Deane Borough '
#                                             'Council',
#                            'organisation_subtype': 'NMD',
#                            'organisation_type': 'local-authority',
#                            'slug': 'basingstoke-and-deane',
#                            'start_date': '1974-04-01',
#                            'territory_code': 'ENG',
#                            'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BAN/1974-04-01/'},
#  'bassetlaw': {'common_name': 'Bassetlaw',
#                'election_name': 'Bassetlaw local election',
#                'end_date': None,
#                'official_identifier': 'BAE',
#                'official_name': 'Bassetlaw District Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'bassetlaw',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BAE/1974-04-01/'},
#  'bath-and-north-east-somerset': {'common_name': 'Bath and North East Somerset',
#                                   'election_name': 'Bath and North East '
#                                                    'Somerset local election',
#                                   'end_date': None,
#                                   'official_identifier': 'BAS',
#                                   'official_name': 'Bath and North East '
#                                                    'Somerset Council',
#                                   'organisation_subtype': 'UA',
#                                   'organisation_type': 'local-authority',
#                                   'slug': 'bath-and-north-east-somerset',
#                                   'start_date': '1996-04-01',
#                                   'territory_code': 'ENG',
#                                   'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BAS/1996-04-01/'},
#  'bedford': {'common_name': 'Bedford Borough Council',
#              'election_name': 'Bedford Borough Council',
#              'end_date': None,
#              'official_identifier': 'BDF',
#              'official_name': 'Bedford Borough Council',
#              'organisation_subtype': 'UA',
#              'organisation_type': 'local-authority',
#              'slug': 'bedford',
#              'start_date': '2009-04-01',
#              'territory_code': 'ENG',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BDF/2009-04-01/'},
#  'bedfordshire': {'common_name': 'Bedfordshire Police',
#                   'election_name': 'Police and Crime Commissioner for '
#                                    'Bedfordshire Police',
#                   'end_date': None,
#                   'official_identifier': 'bedfordshire',
#                   'official_name': 'Bedfordshire Police',
#                   'organisation_subtype': '',
#                   'organisation_type': 'police-area',
#                   'slug': 'bedfordshire',
#                   'start_date': '2012-11-15',
#                   'territory_code': 'ENG',
#                   'url': 'http://elections.democracyclub.org.uk/api/organisations/police-area/bedfordshire/2012-11-15/'},
#  'belfast': {'common_name': 'Belfast',
#              'election_name': 'Belfast local election',
#              'end_date': None,
#              'official_identifier': 'BFS',
#              'official_name': 'Belfast City Council',
#              'organisation_subtype': '',
#              'organisation_type': 'local-authority',
#              'slug': 'belfast',
#              'start_date': '2015-04-01',
#              'territory_code': 'NIR',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BFS/2015-04-01/'},
#  'bexley': {'common_name': 'Bexley',
#             'election_name': 'Bexley local election',
#             'end_date': None,
#             'official_identifier': 'BEX',
#             'official_name': 'London Borough of Bexley',
#             'organisation_subtype': 'LBO',
#             'organisation_type': 'local-authority',
#             'slug': 'bexley',
#             'start_date': '1965-04-01',
#             'territory_code': 'ENG',
#             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BEX/1965-04-01/'},
#  'birmingham': {'common_name': 'Birmingham',
#                 'election_name': 'Birmingham local election',
#                 'end_date': None,
#                 'official_identifier': 'BIR',
#                 'official_name': 'Birmingham City Council',
#                 'organisation_subtype': 'MD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'birmingham',
#                 'start_date': '1986-07-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BIR/1986-07-01/'},
#  'blaby': {'common_name': 'Blaby',
#            'election_name': 'Blaby local election',
#            'end_date': None,
#            'official_identifier': 'BLA',
#            'official_name': 'Blaby District Council',
#            'organisation_subtype': 'NMD',
#            'organisation_type': 'local-authority',
#            'slug': 'blaby',
#            'start_date': '1974-04-01',
#            'territory_code': 'ENG',
#            'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BLA/1974-04-01/'},
#  'blackburn-with-darwen': {'common_name': 'Blackburn with Darwen',
#                            'election_name': 'Blackburn with Darwen local '
#                                             'election',
#                            'end_date': None,
#                            'official_identifier': 'BBD',
#                            'official_name': 'Blackburn with Darwen Borough '
#                                             'Council',
#                            'organisation_subtype': 'UA',
#                            'organisation_type': 'local-authority',
#                            'slug': 'blackburn-with-darwen',
#                            'start_date': '1998-04-01',
#                            'territory_code': 'ENG',
#                            'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BBD/1998-04-01/'},
#  'blackpool': {'common_name': 'Blackpool',
#                'election_name': 'Blackpool local election',
#                'end_date': None,
#                'official_identifier': 'BPL',
#                'official_name': 'Blackpool Borough Council',
#                'organisation_subtype': 'UA',
#                'organisation_type': 'local-authority',
#                'slug': 'blackpool',
#                'start_date': '1998-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BPL/1998-04-01/'},
#  'blaenau-gwent': {'common_name': 'Blaenau Gwent',
#                    'election_name': 'Blaenau Gwent local election',
#                    'end_date': None,
#                    'official_identifier': 'BGW',
#                    'official_name': 'Blaenau Gwent County Borough Council',
#                    'organisation_subtype': 'UA',
#                    'organisation_type': 'local-authority',
#                    'slug': 'blaenau-gwent',
#                    'start_date': '1996-04-01',
#                    'territory_code': 'WLS',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BGW/1996-04-01/'},
#  'bolsover': {'common_name': 'Bolsover',
#               'election_name': 'Bolsover local election',
#               'end_date': None,
#               'official_identifier': 'BOS',
#               'official_name': 'Bolsover District Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'bolsover',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BOS/1974-04-01/'},
#  'bolton': {'common_name': 'Bolton',
#             'election_name': 'Bolton local election',
#             'end_date': None,
#             'official_identifier': 'BOL',
#             'official_name': 'Bolton Metropolitan Borough Council',
#             'organisation_subtype': 'MD',
#             'organisation_type': 'local-authority',
#             'slug': 'bolton',
#             'start_date': '1974-04-01',
#             'territory_code': 'ENG',
#             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BOL/1974-04-01/'},
#  'boston': {'common_name': 'Boston',
#             'election_name': 'Boston local election',
#             'end_date': None,
#             'official_identifier': 'BOT',
#             'official_name': 'Boston Borough Council',
#             'organisation_subtype': 'NMD',
#             'organisation_type': 'local-authority',
#             'slug': 'boston',
#             'start_date': '1974-04-01',
#             'territory_code': 'ENG',
#             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BOT/1974-04-01/'},
#  'bournemouth': {'common_name': 'Bournemouth',
#                  'election_name': 'Bournemouth local election',
#                  'end_date': None,
#                  'official_identifier': 'BMH',
#                  'official_name': 'Bournemouth Borough Council',
#                  'organisation_subtype': 'UA',
#                  'organisation_type': 'local-authority',
#                  'slug': 'bournemouth',
#                  'start_date': '1997-04-01',
#                  'territory_code': 'ENG',
#                  'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BMH/1997-04-01/'},
#  'bracknell-forest': {'common_name': 'Bracknell Forest',
#                       'election_name': 'Bracknell Forest local election',
#                       'end_date': None,
#                       'official_identifier': 'BRC',
#                       'official_name': 'Bracknell Forest Council',
#                       'organisation_subtype': 'UA',
#                       'organisation_type': 'local-authority',
#                       'slug': 'bracknell-forest',
#                       'start_date': '1998-04-01',
#                       'territory_code': 'ENG',
#                       'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRC/1998-04-01/'},
#  'bradford': {'common_name': 'Bradford',
#               'election_name': 'Bradford local election',
#               'end_date': None,
#               'official_identifier': 'BRD',
#               'official_name': 'City of Bradford Metropolitan District Council',
#               'organisation_subtype': 'MD',
#               'organisation_type': 'local-authority',
#               'slug': 'bradford',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRD/1974-04-01/'},
#  'braintree': {'common_name': 'Braintree',
#                'election_name': 'Braintree local election',
#                'end_date': None,
#                'official_identifier': 'BRA',
#                'official_name': 'Braintree District Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'braintree',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRA/1974-04-01/'},
#  'breckland': {'common_name': 'Breckland',
#                'election_name': 'Breckland local election',
#                'end_date': None,
#                'official_identifier': 'BRE',
#                'official_name': 'Breckland District Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'breckland',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRE/1974-04-01/'},
#  'brent': {'common_name': 'Brent',
#            'election_name': 'Brent local election',
#            'end_date': None,
#            'official_identifier': 'BEN',
#            'official_name': 'London Borough of Brent',
#            'organisation_subtype': 'LBO',
#            'organisation_type': 'local-authority',
#            'slug': 'brent',
#            'start_date': '1965-04-01',
#            'territory_code': 'ENG',
#            'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BEN/1965-04-01/'},
#  'brentwood': {'common_name': 'Brentwood',
#                'election_name': 'Brentwood local election',
#                'end_date': None,
#                'official_identifier': 'BRW',
#                'official_name': 'Brentwood Borough Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'brentwood',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRW/1974-04-01/'},
#  'bridgend': {'common_name': 'Bridgend',
#               'election_name': 'Bridgend local election',
#               'end_date': None,
#               'official_identifier': 'BGE',
#               'official_name': 'Bridgend County Borough Council',
#               'organisation_subtype': 'UA',
#               'organisation_type': 'local-authority',
#               'slug': 'bridgend',
#               'start_date': '1996-04-01',
#               'territory_code': 'WLS',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BGE/1996-04-01/'},
#  'brighton-and-hove': {'common_name': 'Brighton and Hove',
#                        'election_name': 'Brighton and Hove local election',
#                        'end_date': None,
#                        'official_identifier': 'BNH',
#                        'official_name': 'Brighton and Hove City Council',
#                        'organisation_subtype': 'UA',
#                        'organisation_type': 'local-authority',
#                        'slug': 'brighton-and-hove',
#                        'start_date': '1997-04-01',
#                        'territory_code': 'ENG',
#                        'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BNH/1997-04-01/'},
#  'bristol': {'common_name': 'Bristol City Council',
#              'election_name': 'Bristol City Council',
#              'end_date': None,
#              'official_identifier': 'BST',
#              'official_name': 'Bristol City Council',
#              'organisation_subtype': 'UA',
#              'organisation_type': 'local-authority',
#              'slug': 'bristol',
#              'start_date': '1996-04-01',
#              'territory_code': 'ENG',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BST/1996-04-01/'},
#  'broadland': {'common_name': 'Broadland',
#                'election_name': 'Broadland local election',
#                'end_date': None,
#                'official_identifier': 'BRO',
#                'official_name': 'Broadland District Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'broadland',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRO/1974-04-01/'},
#  'bromley': {'common_name': 'Bromley',
#              'election_name': 'Bromley local election',
#              'end_date': None,
#              'official_identifier': 'BRY',
#              'official_name': 'London Borough of Bromley',
#              'organisation_subtype': 'LBO',
#              'organisation_type': 'local-authority',
#              'slug': 'bromley',
#              'start_date': '1965-04-01',
#              'territory_code': 'ENG',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRY/1965-04-01/'},
#  'bromsgrove': {'common_name': 'Bromsgrove',
#                 'election_name': 'Bromsgrove local election',
#                 'end_date': None,
#                 'official_identifier': 'BRM',
#                 'official_name': 'Bromsgrove District Council',
#                 'organisation_subtype': 'NMD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'bromsgrove',
#                 'start_date': '1974-04-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRM/1974-04-01/'},
#  'broxbourne': {'common_name': 'Broxbourne',
#                 'election_name': 'Broxbourne local election',
#                 'end_date': None,
#                 'official_identifier': 'BRX',
#                 'official_name': 'Broxbourne Borough Council',
#                 'organisation_subtype': 'NMD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'broxbourne',
#                 'start_date': '1974-04-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRX/1974-04-01/'},
#  'broxtowe': {'common_name': 'Broxtowe',
#               'election_name': 'Broxtowe local election',
#               'end_date': None,
#               'official_identifier': 'BRT',
#               'official_name': 'Broxtowe Borough Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'broxtowe',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BRT/1974-04-01/'},
#  'buckinghamshire': {'common_name': 'Buckinghamshire',
#                      'election_name': 'Buckinghamshire local election',
#                      'end_date': None,
#                      'official_identifier': 'BKM',
#                      'official_name': 'Buckinghamshire County Council',
#                      'organisation_subtype': 'CTY',
#                      'organisation_type': 'local-authority',
#                      'slug': 'buckinghamshire',
#                      'start_date': '1997-04-01',
#                      'territory_code': 'ENG',
#                      'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BKM/1997-04-01/'},
#  'burnley': {'common_name': 'Burnley',
#              'election_name': 'Burnley local election',
#              'end_date': None,
#              'official_identifier': 'BUN',
#              'official_name': 'Burnley Borough Council',
#              'organisation_subtype': 'NMD',
#              'organisation_type': 'local-authority',
#              'slug': 'burnley',
#              'start_date': '1974-04-01',
#              'territory_code': 'ENG',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BUN/1974-04-01/'},
#  'bury': {'common_name': 'Bury',
#           'election_name': 'Bury local election',
#           'end_date': None,
#           'official_identifier': 'BUR',
#           'official_name': 'Bury Metropolitan Borough Council',
#           'organisation_subtype': 'MD',
#           'organisation_type': 'local-authority',
#           'slug': 'bury',
#           'start_date': '1974-04-01',
#           'territory_code': 'ENG',
#           'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/BUR/1974-04-01/'},
#  'caerphilly': {'common_name': 'Caerphilly',
#                 'election_name': 'Caerphilly local election',
#                 'end_date': None,
#                 'official_identifier': 'CAY',
#                 'official_name': 'Caerphilly County Borough Council',
#                 'organisation_subtype': 'UA',
#                 'organisation_type': 'local-authority',
#                 'slug': 'caerphilly',
#                 'start_date': '1996-04-01',
#                 'territory_code': 'WLS',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CAY/1996-04-01/'},
#  'calderdale': {'common_name': 'Calderdale',
#                 'election_name': 'Calderdale local election',
#                 'end_date': None,
#                 'official_identifier': 'CLD',
#                 'official_name': 'Calderdale Metropolitan Borough Council',
#                 'organisation_subtype': 'MD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'calderdale',
#                 'start_date': '1974-04-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CLD/1974-04-01/'},
#  'cambridge': {'common_name': 'Cambridge',
#                'election_name': 'Cambridge local election',
#                'end_date': None,
#                'official_identifier': 'CAB',
#                'official_name': 'Cambridge City Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'cambridge',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CAB/1974-04-01/'},
#  'cambridgeshire': {'common_name': 'Cambridgeshire',
#                     'election_name': 'Cambridgeshire local election',
#                     'end_date': None,
#                     'official_identifier': 'CAM',
#                     'official_name': 'Cambridgeshire County Council',
#                     'organisation_subtype': 'CTY',
#                     'organisation_type': 'local-authority',
#                     'slug': 'cambridgeshire',
#                     'start_date': '1998-04-01',
#                     'territory_code': 'ENG',
#                     'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CAM/1998-04-01/'},
#  'cambridgeshire-and-peterborough': {'common_name': 'Cambridgeshire and '
#                                                     'Peterborough Combined '
#                                                     'Authority',
#                                      'election_name': 'Cambridgeshire and '
#                                                       'Peterborough Combined '
#                                                       'Authority',
#                                      'end_date': None,
#                                      'official_identifier': 'cambridgeshire-and-peterborough',
#                                      'official_name': 'Cambridgeshire and '
#                                                       'Peterborough Combined '
#                                                       'Authority',
#                                      'organisation_subtype': '',
#                                      'organisation_type': 'combined-authority',
#                                      'slug': 'cambridgeshire-and-peterborough',
#                                      'start_date': '2017-03-03',
#                                      'territory_code': 'ENG',
#                                      'url': 'http://elections.democracyclub.org.uk/api/organisations/combined-authority/cambridgeshire-and-peterborough/2017-03-03/'},
#  'camden': {'common_name': 'Camden',
#             'election_name': 'Camden local election',
#             'end_date': None,
#             'official_identifier': 'CMD',
#             'official_name': 'London Borough of Camden',
#             'organisation_subtype': 'LBO',
#             'organisation_type': 'local-authority',
#             'slug': 'camden',
#             'start_date': '1965-04-01',
#             'territory_code': 'ENG',
#             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CMD/1965-04-01/'},
#  'cannock-chase': {'common_name': 'Cannock Chase',
#                    'election_name': 'Cannock Chase local election',
#                    'end_date': None,
#                    'official_identifier': 'CAN',
#                    'official_name': 'Cannock Chase District Council',
#                    'organisation_subtype': 'NMD',
#                    'organisation_type': 'local-authority',
#                    'slug': 'cannock-chase',
#                    'start_date': '1974-04-01',
#                    'territory_code': 'ENG',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CAN/1974-04-01/'},
#  'canterbury': {'common_name': 'Canterbury',
#                 'election_name': 'Canterbury local election',
#                 'end_date': None,
#                 'official_identifier': 'CAT',
#                 'official_name': 'Canterbury City Council',
#                 'organisation_subtype': 'NMD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'canterbury',
#                 'start_date': '1974-04-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CAT/1974-04-01/'},
#  'cardiff': {'common_name': 'Cardiff',
#              'election_name': 'Cardiff local election',
#              'end_date': None,
#              'official_identifier': 'CRF',
#              'official_name': 'City of Cardiff Council',
#              'organisation_subtype': 'UA',
#              'organisation_type': 'local-authority',
#              'slug': 'cardiff',
#              'start_date': '1996-04-01',
#              'territory_code': 'WLS',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CRF/1996-04-01/'},
#  'carlisle': {'common_name': 'Carlisle',
#               'election_name': 'Carlisle local election',
#               'end_date': None,
#               'official_identifier': 'CAR',
#               'official_name': 'Carlisle City Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'carlisle',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CAR/1974-04-01/'},
#  'carmarthenshire': {'common_name': 'Carmarthenshire',
#                      'election_name': 'Carmarthenshire local election',
#                      'end_date': None,
#                      'official_identifier': 'CMN',
#                      'official_name': 'Carmarthenshire County Council',
#                      'organisation_subtype': 'UA',
#                      'organisation_type': 'local-authority',
#                      'slug': 'carmarthenshire',
#                      'start_date': '1996-04-01',
#                      'territory_code': 'WLS',
#                      'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CMN/1996-04-01/'},
#  'castle-point': {'common_name': 'Castle Point',
#                   'election_name': 'Castle Point local election',
#                   'end_date': None,
#                   'official_identifier': 'CAS',
#                   'official_name': 'Castle Point Borough Council',
#                   'organisation_subtype': 'NMD',
#                   'organisation_type': 'local-authority',
#                   'slug': 'castle-point',
#                   'start_date': '1974-04-01',
#                   'territory_code': 'ENG',
#                   'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CAS/1974-04-01/'},
#  'causeway-coast-and-glens': {'common_name': 'Causeway Coast and Glens',
#                               'election_name': 'Causeway Coast and Glens local '
#                                                'election',
#                               'end_date': None,
#                               'official_identifier': 'CCG',
#                               'official_name': 'Causeway Coast and Glens '
#                                                'Borough Council',
#                               'organisation_subtype': '',
#                               'organisation_type': 'local-authority',
#                               'slug': 'causeway-coast-and-glens',
#                               'start_date': '2015-04-01',
#                               'territory_code': 'NIR',
#                               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CCG/2015-04-01/'},
#  'central-bedfordshire': {'common_name': 'Central Bedfordshire',
#                           'election_name': 'Central Bedfordshire local '
#                                            'election',
#                           'end_date': None,
#                           'official_identifier': 'CBF',
#                           'official_name': 'Central Bedfordshire Council',
#                           'organisation_subtype': 'UA',
#                           'organisation_type': 'local-authority',
#                           'slug': 'central-bedfordshire',
#                           'start_date': '2009-04-01',
#                           'territory_code': 'ENG',
#                           'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CBF/2009-04-01/'},
#  'ceredigion': {'common_name': 'Ceredigion',
#                 'election_name': 'Ceredigion local election',
#                 'end_date': None,
#                 'official_identifier': 'CGN',
#                 'official_name': 'Ceredigion County Council',
#                 'organisation_subtype': 'UA',
#                 'organisation_type': 'local-authority',
#                 'slug': 'ceredigion',
#                 'start_date': '1996-04-01',
#                 'territory_code': 'WLS',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CGN/1996-04-01/'},
#  'charnwood': {'common_name': 'Charnwood',
#                'election_name': 'Charnwood local election',
#                'end_date': None,
#                'official_identifier': 'CHA',
#                'official_name': 'Charnwood Borough Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'charnwood',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CHA/1974-04-01/'},
#  'chelmsford': {'common_name': 'Chelmsford',
#                 'election_name': 'Chelmsford local election',
#                 'end_date': None,
#                 'official_identifier': 'CHL',
#                 'official_name': 'Chelmsford City Council',
#                 'organisation_subtype': 'NMD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'chelmsford',
#                 'start_date': '1974-04-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CHL/1974-04-01/'},
#  'cheltenham': {'common_name': 'Cheltenham',
#                 'election_name': 'Cheltenham local election',
#                 'end_date': None,
#                 'official_identifier': 'CHT',
#                 'official_name': 'Cheltenham Borough Council',
#                 'organisation_subtype': 'NMD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'cheltenham',
#                 'start_date': '1974-04-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CHT/1974-04-01/'},
#  'cherwell': {'common_name': 'Cherwell',
#               'election_name': 'Cherwell local election',
#               'end_date': None,
#               'official_identifier': 'CHR',
#               'official_name': 'Cherwell District Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'cherwell',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CHR/1974-04-01/'},
#  'cheshire': {'common_name': 'Cheshire Constabulary',
#               'election_name': 'Police and Crime Commissioner for Cheshire '
#                                'Constabulary',
#               'end_date': None,
#               'official_identifier': 'cheshire',
#               'official_name': 'Cheshire Constabulary',
#               'organisation_subtype': '',
#               'organisation_type': 'police-area',
#               'slug': 'cheshire',
#               'start_date': '2012-11-15',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/police-area/cheshire/2012-11-15/'},
#  'cheshire-east': {'common_name': 'Cheshire East',
#                    'election_name': 'Cheshire East local election',
#                    'end_date': None,
#                    'official_identifier': 'CHE',
#                    'official_name': 'Cheshire East Council',
#                    'organisation_subtype': 'UA',
#                    'organisation_type': 'local-authority',
#                    'slug': 'cheshire-east',
#                    'start_date': '2009-04-01',
#                    'territory_code': 'ENG',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/CHE/2009-04-01/'},
#  'cheshire-west-and-chester': {'common_name': 'Cheshire West and Chester',
#                                'election_name': 'Cheshire West and Chester '
#                                                 'local election',
# ...
#                  'end_date': None,
#                  'official_identifier': 'west-mercia',
#                  'official_name': 'West Mercia Police',
#                  'organisation_subtype': '',
#                  'organisation_type': 'police-area',
#                  'slug': 'west-mercia',
#                  'start_date': '2012-11-15',
#                  'territory_code': 'ENG',
#                  'url': 'http://elections.democracyclub.org.uk/api/organisations/police-area/west-mercia/2012-11-15/'},
#  'west-midlands': {'common_name': 'West Midlands Police',
#                    'election_name': 'Police and Crime Commissioner for West '
#                                     'Midlands Police',
#                    'end_date': None,
#                    'official_identifier': 'west-midlands',
#                    'official_name': 'West Midlands Police',
#                    'organisation_subtype': '',
#                    'organisation_type': 'police-area',
#                    'slug': 'west-midlands',
#                    'start_date': '2012-11-15',
#                    'territory_code': 'ENG',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/police-area/west-midlands/2012-11-15/'},
#  'west-of-england': {'common_name': 'West of England Combined Authority',
#                      'election_name': 'West of England Combined Authority',
#                      'end_date': None,
#                      'official_identifier': 'west-of-england',
#                      'official_name': 'West of England Combined Authority',
#                      'organisation_subtype': '',
#                      'organisation_type': 'combined-authority',
#                      'slug': 'west-of-england',
#                      'start_date': '2017-02-09',
#                      'territory_code': 'ENG',
#                      'url': 'http://elections.democracyclub.org.uk/api/organisations/combined-authority/west-of-england/2017-02-09/'},
#  'west-oxfordshire': {'common_name': 'West Oxfordshire',
#                       'election_name': 'West Oxfordshire local election',
#                       'end_date': None,
#                       'official_identifier': 'WOX',
#                       'official_name': 'West Oxfordshire District Council',
#                       'organisation_subtype': 'NMD',
#                       'organisation_type': 'local-authority',
#                       'slug': 'west-oxfordshire',
#                       'start_date': '1974-04-01',
#                       'territory_code': 'ENG',
#                       'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WOX/1974-04-01/'},
#  'west-somerset': {'common_name': 'West Somerset',
#                    'election_name': 'West Somerset local election',
#                    'end_date': None,
#                    'official_identifier': 'WSO',
#                    'official_name': 'West Somerset District Council',
#                    'organisation_subtype': 'NMD',
#                    'organisation_type': 'local-authority',
#                    'slug': 'west-somerset',
#                    'start_date': '1974-04-01',
#                    'territory_code': 'ENG',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WSO/1974-04-01/'},
#  'west-sussex': {'common_name': 'West Sussex',
#                  'election_name': 'West Sussex local election',
#                  'end_date': None,
#                  'official_identifier': 'WSX',
#                  'official_name': 'West Sussex County Council',
#                  'organisation_subtype': 'CTY',
#                  'organisation_type': 'local-authority',
#                  'slug': 'west-sussex',
#                  'start_date': '1974-04-01',
#                  'territory_code': 'ENG',
#                  'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WSX/1974-04-01/'},
#  'west-yorkshire': {'common_name': 'West Yorkshire Police',
#                     'election_name': 'Police and Crime Commissioner for West '
#                                      'Yorkshire Police',
#                     'end_date': None,
#                     'official_identifier': 'west-yorkshire',
#                     'official_name': 'West Yorkshire Police',
#                     'organisation_subtype': '',
#                     'organisation_type': 'police-area',
#                     'slug': 'west-yorkshire',
#                     'start_date': '2012-11-15',
#                     'territory_code': 'ENG',
#                     'url': 'http://elections.democracyclub.org.uk/api/organisations/police-area/west-yorkshire/2012-11-15/'},
#  'westminster': {'common_name': 'Westminster',
#                  'election_name': 'Westminster local election',
#                  'end_date': None,
#                  'official_identifier': 'WSM',
#                  'official_name': 'City of Westminster',
#                  'organisation_subtype': 'LBO',
#                  'organisation_type': 'local-authority',
#                  'slug': 'westminster',
#                  'start_date': '1965-04-01',
#                  'territory_code': 'ENG',
#                  'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WSM/1965-04-01/'},
#  'weymouth-and-portland': {'common_name': 'Weymouth and Portland',
#                            'election_name': 'Weymouth and Portland local '
#                                             'election',
#                            'end_date': None,
#                            'official_identifier': 'WEY',
#                            'official_name': 'Weymouth and Portland Borough '
#                                             'Council',
#                            'organisation_subtype': 'NMD',
#                            'organisation_type': 'local-authority',
#                            'slug': 'weymouth-and-portland',
#                            'start_date': '1974-04-01',
#                            'territory_code': 'ENG',
#                            'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WEY/1974-04-01/'},
#  'wigan': {'common_name': 'Wigan',
#            'election_name': 'Wigan local election',
#            'end_date': None,
#            'official_identifier': 'WGN',
#            'official_name': 'Wigan Metropolitan Borough Council',
#            'organisation_subtype': 'MD',
#            'organisation_type': 'local-authority',
#            'slug': 'wigan',
#            'start_date': '1974-04-01',
#            'territory_code': 'ENG',
#            'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WGN/1974-04-01/'},
#  'wiltshire': {'common_name': 'Wiltshire Police',
#                'election_name': 'Police and Crime Commissioner for Wiltshire '
#                                 'Police',
#                'end_date': None,
#                'official_identifier': 'wiltshire',
#                'official_name': 'Wiltshire Police',
#                'organisation_subtype': '',
#                'organisation_type': 'police-area',
#                'slug': 'wiltshire',
#                'start_date': '2012-11-15',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/police-area/wiltshire/2012-11-15/'},
#  'winchester': {'common_name': 'Winchester',
#                 'election_name': 'Winchester local election',
#                 'end_date': None,
#                 'official_identifier': 'WIN',
#                 'official_name': 'Winchester City Council',
#                 'organisation_subtype': 'NMD',
#                 'organisation_type': 'local-authority',
#                 'slug': 'winchester',
#                 'start_date': '1974-04-01',
#                 'territory_code': 'ENG',
#                 'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WIN/1974-04-01/'},
#  'windsor-and-maidenhead': {'common_name': 'Windsor and Maidenhead',
#                             'election_name': 'Windsor and Maidenhead local '
#                                              'election',
#                             'end_date': None,
#                             'official_identifier': 'WNM',
#                             'official_name': 'Royal Borough of Windsor and '
#                                              'Maidenhead',
#                             'organisation_subtype': 'UA',
#                             'organisation_type': 'local-authority',
#                             'slug': 'windsor-and-maidenhead',
#                             'start_date': '1998-04-01',
#                             'territory_code': 'ENG',
#                             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WNM/1998-04-01/'},
#  'wirral': {'common_name': 'Wirral',
#             'election_name': 'Wirral local election',
#             'end_date': None,
#             'official_identifier': 'WRL',
#             'official_name': 'Wirral Borough Council',
#             'organisation_subtype': 'MD',
#             'organisation_type': 'local-authority',
#             'slug': 'wirral',
#             'start_date': '1974-04-01',
#             'territory_code': 'ENG',
#             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WRL/1974-04-01/'},
#  'woking': {'common_name': 'Woking',
#             'election_name': 'Woking local election',
#             'end_date': None,
#             'official_identifier': 'WOI',
#             'official_name': 'Woking Borough Council',
#             'organisation_subtype': 'NMD',
#             'organisation_type': 'local-authority',
#             'slug': 'woking',
#             'start_date': '1974-04-01',
#             'territory_code': 'ENG',
#             'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WOI/1974-04-01/'},
#  'wokingham': {'common_name': 'Wokingham',
#                'election_name': 'Wokingham local election',
#                'end_date': None,
#                'official_identifier': 'WOK',
#                'official_name': 'Wokingham Borough Council',
#                'organisation_subtype': 'UA',
#                'organisation_type': 'local-authority',
#                'slug': 'wokingham',
#                'start_date': '1998-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WOK/1998-04-01/'},
#  'wolverhampton': {'common_name': 'Wolverhampton',
#                    'election_name': 'Wolverhampton local election',
#                    'end_date': None,
#                    'official_identifier': 'WLV',
#                    'official_name': 'City of Wolverhampton Council',
#                    'organisation_subtype': 'MD',
#                    'organisation_type': 'local-authority',
#                    'slug': 'wolverhampton',
#                    'start_date': '1974-04-01',
#                    'territory_code': 'ENG',
#                    'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WLV/1974-04-01/'},
#  'worcester': {'common_name': 'Worcester',
#                'election_name': 'Worcester local election',
#                'end_date': None,
#                'official_identifier': 'WOC',
#                'official_name': 'Worcester City Council',
#                'organisation_subtype': 'NMD',
#                'organisation_type': 'local-authority',
#                'slug': 'worcester',
#                'start_date': '1974-04-01',
#                'territory_code': 'ENG',
#                'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WOC/1974-04-01/'},
#  'worcestershire': {'common_name': 'Worcestershire',
#                     'election_name': 'Worcestershire local election',
#                     'end_date': None,
#                     'official_identifier': 'WOR',
#                     'official_name': 'Worcestershire County Council',
#                     'organisation_subtype': 'CTY',
#                     'organisation_type': 'local-authority',
#                     'slug': 'worcestershire',
#                     'start_date': '1998-04-01',
#                     'territory_code': 'ENG',
#                     'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WOR/1998-04-01/'},
#  'worthing': {'common_name': 'Worthing',
#               'election_name': 'Worthing local election',
#               'end_date': None,
#               'official_identifier': 'WOT',
#               'official_name': 'Worthing Borough Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'worthing',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WOT/1974-04-01/'},
#  'wrexham': {'common_name': 'Wrexham',
#              'election_name': 'Wrexham local election',
#              'end_date': None,
#              'official_identifier': 'WRX',
#              'official_name': 'Wrexham County Borough Council',
#              'organisation_subtype': 'UA',
#              'organisation_type': 'local-authority',
#              'slug': 'wrexham',
#              'start_date': '1996-04-01',
#              'territory_code': 'WLS',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WRX/1996-04-01/'},
#  'wychavon': {'common_name': 'Wychavon',
#               'election_name': 'Wychavon local election',
#               'end_date': None,
#               'official_identifier': 'WYC',
#               'official_name': 'Wychavon District Council',
#               'organisation_subtype': 'NMD',
#               'organisation_type': 'local-authority',
#               'slug': 'wychavon',
#               'start_date': '1974-04-01',
#               'territory_code': 'ENG',
#               'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WYC/1974-04-01/'},
#  'wycombe': {'common_name': 'Wycombe',
#              'election_name': 'Wycombe local election',
#              'end_date': None,
#              'official_identifier': 'WYO',
#              'official_name': 'Wycombe District Council',
#              'organisation_subtype': 'NMD',
#              'organisation_type': 'local-authority',
#              'slug': 'wycombe',
#              'start_date': '1974-04-01',
#              'territory_code': 'ENG',
#              'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WYO/1974-04-01/'},
#  'wyre': {'common_name': 'Wyre',
#           'election_name': 'Wyre local election',
#           'end_date': None,
#           'official_identifier': 'WYR',
#           'official_name': 'Wyre Borough Council',
#           'organisation_subtype': 'NMD',
#           'organisation_type': 'local-authority',
#           'slug': 'wyre',
#           'start_date': '1974-04-01',
#           'territory_code': 'ENG',
#           'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WYR/1974-04-01/'},
#  'wyre-forest': {'common_name': 'Wyre Forest',
#                  'election_name': 'Wyre Forest local election',
#                  'end_date': None,
#                  'official_identifier': 'WYE',
#                  'official_name': 'Wyre Forest District Council',
#                  'organisation_subtype': 'NMD',
#                  'organisation_type': 'local-authority',
#                  'slug': 'wyre-forest',
#                  'start_date': '1974-04-01',
#                  'territory_code': 'ENG',
#                  'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/WYE/1974-04-01/'},
#  'york': {'common_name': 'York',
#           'election_name': 'York local election',
#           'end_date': None,
#           'official_identifier': 'YOR',
#           'official_name': 'City of York Council',
#           'organisation_subtype': 'UA',
#           'organisation_type': 'local-authority',
#           'slug': 'york',
#           'start_date': '1996-04-01',
#           'territory_code': 'ENG',
#           'url': 'http://elections.democracyclub.org.uk/api/organisations/local-authority/YOR/1996-04-01/'}}

# %%
# GET ALL FUTURE ELECTIONS

url_ee = 'https://elections.democracyclub.org.uk/api/elections.json?future=1'
df_ee = pd.DataFrame()

while url_ee:
    print(url_ee)
    res_ee = requests.get(url_ee)
    res_ee.raise_for_status()
    data_ee = res_ee.json()
    df_ee_subset = pd.DataFrame(data_ee['results'])
    df_ee = pd.concat([df_ee, df_ee_subset], ignore_index=True)
    url_ee = data_ee['next']
print('Pulled ' + str(len(df_ee)) + ' elections from the Every Election API')
# Out:
# 'https://elections.democracyclub.org.uk/api/elections.json?future=1'
# 'Pulled 60 elections from the Every Election API'

# %%
print(df_ee)
# print(df_ee.loc[df_ee['election_id'] == 'local.torridge.hartland-and-bradworthy.by.2018-07-26'])
# print('-------------')
# print(df_ee.loc[df_ee['election_id'] == 'local.torridge.hartland-and-bradworthy.by.2018-07-26','division'])
# print('-------------')
# print(df_ee.loc[df_ee['election_id'] == 'local.torridge.hartland-and-bradworthy.by.2018-07-26']['election_type'])
# print('-------------')
# print(df_ee.loc[df_ee['election_id'] == 'local.torridge.hartland-and-bradworthy.by.2018-07-26']['organisation'])
# Out:
#    children  current                                           division  \
# 57       []     True  {'divisionset': {'start_date': '2004-12-02', '...
#
#         elected_role                                        election_id  \
# 57  Local Councillor  local.torridge.hartland-and-bradworthy.by.2018...
#
#    election_subtype                                     election_title  \
# 57             None  Torridge local election Hartland and Bradworth...
#
#                                         election_type explanation  \
# 57  {'name': 'Local elections', 'election_type': '...        None
#
#                         group group_type metadata  \
# 57  local.torridge.2018-07-26       None     None
#
#                                          organisation poll_open_date  \
# 57  {'url': 'http://elections.democracyclub.org.uk...     2018-07-26
#
#     seats_contested tmp_election_id  \
# 57              1.0            None
#
#                                         voting_system
# 57  {'slug': 'FPTP', 'name': 'First-past-the-post'...
# '-------------'
# 57    {'divisionset': {'start_date': '2004-12-02', '...
# Name: division, dtype: object
# '-------------'
# 57    {'name': 'Local elections', 'election_type': '...
# Name: election_type, dtype: object
# '-------------'
# 57    {'url': 'http://elections.democracyclub.org.uk...
# Name: organisation, dtype: object

# %%
# BUILD UP A DATASET OF BALLOTS

ballots = {}

for i, row in df_ee.iterrows():

    # Heiarchy of election data: 
    #    Election type > [Election subtype] > [Organisation] > [Division] > [By-election] > Date polls open

    # We want to create a nested dictionary that follows this hierarchy. I.e. a dictionary of election types,
    # each containing a dictionary of organisations, each containing a dictionary of ballots (division.date_poll_opens).
    
    # Later on we will add a dictionary of candidates for each ballot. 
    
    # In the election object we pulled from elections.dc, if group_type is none then we are at the bottom of 
    # the hiearchy, so we know this is a ballot (and the election_id is therefore our ballot_id)
    
    if row['group_type'] is None:
        
        # Election Type
        electionType = row['election_type']['election_type']
        if electionType not in ballots:
            ballots[electionType] = {}
        
        # Organisation
        organisationId = row['group']
        if organisationId not in ballots[electionType]:
            ballots[electionType][organisationId] = {
                'organisation_slug': row['organisation']['slug'],  # We need this to lookup to our master list of orgs
                'ballots': {}
            }
        
        # Ballots
        ballotId = row['election_id']
        ballots[electionType][organisationId]['ballots'][ballotId] = {
            'ballot_id': ballotId,
            'ynr_election_id': organisationId,
            'election_title': row['election_title'],
            'election_type': electionType,
            'election_type_name': row['election_type']['name'],
            'elected_role': row['elected_role'],
            'division_name': row['division']['name'],
            'division_id': row['division']['official_identifier'],
            'seats_total': row['division']['seats_total'],
            'organisation_name': row['organisation']['common_name'],
            'organisation_type': row['organisation']['organisation_type'],            
            'organisation_subtype': row['organisation']['organisation_subtype'],
            'poll_open_date': row['poll_open_date']
        }

# %%
# GET CANDIDATE DATA FOR THE ORGANISATIONS OF ALL BALLOTS

# We pull candidate data from YourNextRepresentative (YNR, candidates.democracyclub.org.uk), 
# which identifies elections with the organisation ID (not the ballot ID) and a post ID, so we need to 
# call the candidates API using the organisation_id.
# Of course, we will have multiple ballots for each organisation. So to avoid hitting the API every time, 
# we'll build up a standalone list of candidates and thus only access the API for new orgIds

candidates = {}

for electionType in ballots:
    for orgId in ballots[electionType]:
        for ballotId in ballots[electionType][orgId]['ballots']:
            
            ballot = ballots[electionType][orgId]['ballots'][ballotId]
    
            if orgId not in candidates:

                candidates[orgId] = {}

                url_ynr = "https://candidates.democracyclub.org.uk/media/candidates-%s.csv" % (orgId)
                print(url_ynr)
                
                try:
                    res_ynr = requests.get(url_ynr)
                    res_ynr.raise_for_status()
                    decoded_data_ynr = res_ynr.content.decode('utf-8')
                    data_ynr = list(csv.DictReader(decoded_data_ynr.splitlines(), delimiter=','))
                    print('Pulled ' + str(len(data_ynr)) + ' candidates for ' + orgId)
                    for candidate_ynr in data_ynr:
                        candidates[orgId][candidate_ynr['id']] = dict(candidate_ynr)
                        print(dict(candidate_ynr))
                except requests.exceptions.HTTPError:
                    print('Pulled 0 candidates for ' + orgId)
# Out:
# 'https://candidates.democracyclub.org.uk/media/candidates-local.bury.2018-08-16.csv'
# 'Pulled 0 candidates for local.bury.2018-08-16'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.city-of-london.2018-08-30.csv'
# 'Pulled 0 candidates for local.city-of-london.2018-08-30'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.cornwall.2018-08-23.csv'
# 'Pulled 0 candidates for local.cornwall.2018-08-23'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.cornwall.2018-08-09.csv'
# 'Pulled 0 candidates for local.cornwall.2018-08-09'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.east-devon.2018-09-20.csv'
# 'Pulled 0 candidates for local.east-devon.2018-09-20'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.east-hertfordshire.2018-08-23.csv'
# 'Pulled 0 candidates for local.east-hertfordshire.2018-08-23'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.fife.2018-09-06.csv'
# 'Pulled 0 candidates for local.fife.2018-09-06'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.fylde.2018-08-02.csv'
# 'Pulled 2 candidates for local.fylde.2018-08-02'
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.fylde.2018-08-02',
#  'election_current': 'True',
#  'election_date': '2018-08-02',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49032',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Chris Dixon',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP52',
#  'party_id': 'party:52',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Conservative and Unionist Party',
#  'party_ppc_page_url': '',
#  'post_id': 'DIW:E05005185',
#  'post_label': 'Ansdell',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.fylde.2018-08-02',
#  'election_current': 'True',
#  'election_date': '2018-08-02',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '29010',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Gareth Stuart Nash',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP53',
#  'party_id': 'party:53',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Labour Party',
#  'party_ppc_page_url': '',
#  'post_id': 'DIW:E05005185',
#  'post_label': 'Ansdell',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# 'https://candidates.democracyclub.org.uk/media/candidates-local.kings-lynn-and-west-norfolk.2018-08-02.csv'
# 'Pulled 0 candidates for local.kings-lynn-and-west-norfolk.2018-08-02'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.merthyr-tydfil.2018-07-26.csv'
# 'Pulled 4 candidates for local.merthyr-tydfil.2018-07-26'
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.merthyr-tydfil.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49015',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Jeremy Islwyn Trevor Davies',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': '',
#  'party_id': 'ynmp-party:2',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Independent',
#  'party_ppc_page_url': '',
#  'post_id': 'UTE:W05000710',
#  'post_label': 'Gurnos',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.merthyr-tydfil.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49016',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Laurel Elizabeth Ellis',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP52',
#  'party_id': 'party:52',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Conservative and Unionist Party',
#  'party_ppc_page_url': '',
#  'post_id': 'UTE:W05000710',
#  'post_label': 'Gurnos',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.merthyr-tydfil.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': 'https://www.facebook.com/allyn.hooper',
#  'favourite_biscuits': '',
#  'gender': 'male',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49017',
#  'image_copyright': 'profile-photo',
#  'image_uploading_user': 'sjorford',
#  'image_uploading_user_notes': 'https://www.facebook.com/GurnosLabour/photos/a.212524002720859.1073741829.205739603399299/216704618969464/?type=3&theater',
#  'image_url': 'https://static-candidates.democracyclub.org.uk/media/images/images/49017.png',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Allyn Hooper',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP53',
#  'party_id': 'party:53',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Labour Party',
#  'party_ppc_page_url': '',
#  'post_id': 'UTE:W05000710',
#  'post_label': 'Gurnos',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '877272137412825089',
#  'twitter_username': 'WrAllynHooper',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.merthyr-tydfil.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49018',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Dillan Singh',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': '',
#  'party_id': 'ynmp-party:2',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Independent',
#  'party_ppc_page_url': '',
#  'post_id': 'UTE:W05000710',
#  'post_label': 'Gurnos',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# 'https://candidates.democracyclub.org.uk/media/candidates-local.new-forest.2018-07-26.csv'
# 'Pulled 2 candidates for local.new-forest.2018-07-26'
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.new-forest.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49019',
#  'image_copyright': 'profile-photo',
#  'image_uploading_user': 'fbrc',
#  'image_uploading_user_notes': 'https://www.facebook.com/nflibdems/posts/758253344383381',
#  'image_url': 'https://static-candidates.democracyclub.org.uk/media/images/images/49019.png',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Craig Fletcher',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP90',
#  'party_id': 'party:90',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Liberal Democrats',
#  'party_ppc_page_url': '',
#  'post_id': 'DIW:E05004592',
#  'post_label': 'Fawley, Blackfield and Langley',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.new-forest.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49020',
#  'image_copyright': 'profile-photo',
#  'image_uploading_user': 'fbrc',
#  'image_uploading_user_notes': 'https://www.facebook.com/NFEConservatives/photos/1760597297351670/',
#  'image_url': 'https://static-candidates.democracyclub.org.uk/media/images/images/49020.png',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Merv Langdale',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP52',
#  'party_id': 'party:52',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Conservative and Unionist Party',
#  'party_ppc_page_url': '',
#  'post_id': 'DIW:E05004592',
#  'post_label': 'Fawley, Blackfield and Langley',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# 'https://candidates.democracyclub.org.uk/media/candidates-local.north-east-lincolnshire.2018-07-26.csv'
# 'Pulled 0 candidates for local.north-east-lincolnshire.2018-07-26'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.north-warwickshire.2018-08-23.csv'
# 'Pulled 0 candidates for local.north-warwickshire.2018-08-23'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.north-yorkshire.2018-08-16.csv'
# 'Pulled 0 candidates for local.north-yorkshire.2018-08-16'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.peterborough.2018-08-02.csv'
# 'Pulled 0 candidates for local.peterborough.2018-08-02'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.plymouth.2018-07-26.csv'
# 'Pulled 4 candidates for local.plymouth.2018-07-26'
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.plymouth.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '49013',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Connor Clarke',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP90',
#  'party_id': 'party:90',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Liberal Democrats',
#  'party_ppc_page_url': '',
#  'post_id': 'UTW:E05002096',
#  'post_label': 'Stoke',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.plymouth.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': 'https://www.facebook.com/jemimalaingmoorviewward/',
#  'favourite_biscuits': '',
#  'gender': 'Female',
#  'gss_code': '',
#  'homepage_url': 'http://www.jemimalaing.co.uk/',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '36370',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Jemima Mary Laing',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP53',
#  'party_id': 'party:53',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Labour Party',
#  'party_ppc_page_url': 'http://www.plymouthlabour.org/our_winning_team_for_the_2018_elections',
#  'post_id': 'UTW:E05002096',
#  'post_label': 'Stoke',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '164665800',
#  'twitter_username': 'jemimalaing',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.plymouth.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': 'ForPlymouth@outlook.com',
#  'facebook_page_url': 'https://www.facebook.com/ForPlymouth/',
#  'facebook_personal_url': 'https://www.facebook.com/iuliu.popescu',
#  'favourite_biscuits': '',
#  'gender': 'male',
#  'gss_code': '',
#  'homepage_url': 'http://www.forplymouth.co.uk/',
#  'honorific_prefix': 'iuliu popescu',
#  'honorific_suffix': '',
#  'id': '48234',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Iuliu Popescu',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP6795',
#  'party_id': 'party:6795',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Active For Plymouth',
#  'party_ppc_page_url': 'http://www.forplymouth.co.uk/the-team/',
#  'post_id': 'UTW:E05002096',
#  'post_label': 'Stoke',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '993672212531073024',
#  'twitter_username': 'Active4Plymouth',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.plymouth.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': 'female',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '46393',
#  'image_copyright': 'profile-photo',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': 'Auto imported from Twitter: '
#                                'https://twitter.com/intent/user?user_id=970423613139636226',
#  'image_url': 'https://static-candidates.democracyclub.org.uk/media/images/images/46393.png',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Kathy Watkin',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP52',
#  'party_id': 'party:52',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Conservative and Unionist Party',
#  'party_ppc_page_url': '',
#  'post_id': 'UTW:E05002096',
#  'post_label': 'Stoke',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '970423613139636226',
#  'twitter_username': 'kathy4stoke1',
#  'wikipedia_url': ''}
# 'https://candidates.democracyclub.org.uk/media/candidates-local.redditch.2019-05-02.csv'
# 'Pulled 0 candidates for local.redditch.2019-05-02'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.rushcliffe.2018-08-23.csv'
# 'Pulled 0 candidates for local.rushcliffe.2018-08-23'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.thanet.2018-07-26.csv'
# 'Pulled 0 candidates for local.thanet.2018-07-26'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.torridge.2018-07-26.csv'
# 'Pulled 0 candidates for local.torridge.2018-07-26'
# 'https://candidates.democracyclub.org.uk/media/candidates-local.west-lancashire.2018-07-26.csv'
# 'Pulled 3 candidates for local.west-lancashire.2018-07-26'
# {'birth_date': '1989-03-04',
#  'elected': '',
#  'election': 'local.west-lancashire.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': 'garethdowling@gmail.com',
#  'facebook_page_url': 'https://www.facebook.com/garethdowlingpage/',
#  'facebook_personal_url': 'https://www.facebook.com/GarethDowling',
#  'favourite_biscuits': '',
#  'gender': 'male',
#  'gss_code': '',
#  'homepage_url': 'http://www.garethdowling.co.uk/',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '26818',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Gareth Dowling',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP53',
#  'party_id': 'party:53',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Labour Party',
#  'party_ppc_page_url': '',
#  'post_id': 'DIW:E05005367',
#  'post_label': 'Knowsley',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '128740518',
#  'twitter_username': 'garethdowling',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.west-lancashire.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': 'female',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '44900',
#  'image_copyright': 'profile-photo',
#  'image_uploading_user': 'sjorford',
#  'image_uploading_user_notes': 'http://ourwestlancashire.com/about_us.html',
#  'image_url': 'https://static-candidates.democracyclub.org.uk/media/images/images/44900.png',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Kate Mitchell',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP2642',
#  'party_id': 'party:2642',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Our West Lancashire',
#  'party_ppc_page_url': 'http://ourwestlancashire.com/about_us.html',
#  'post_id': 'DIW:E05005367',
#  'post_label': 'Knowsley',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}
# {'birth_date': '',
#  'elected': '',
#  'election': 'local.west-lancashire.2018-07-26',
#  'election_current': 'True',
#  'election_date': '2018-07-26',
#  'email': '',
#  'facebook_page_url': '',
#  'facebook_personal_url': '',
#  'favourite_biscuits': '',
#  'gender': '',
#  'gss_code': '',
#  'homepage_url': '',
#  'honorific_prefix': '',
#  'honorific_suffix': '',
#  'id': '44901',
#  'image_copyright': '',
#  'image_uploading_user': '',
#  'image_uploading_user_notes': '',
#  'image_url': '',
#  'linkedin_url': '',
#  'mapit_url': '',
#  'name': 'Jeffrey Vernon',
#  'old_person_ids': '',
#  'parlparse_id': '',
#  'party_ec_id': 'PP52',
#  'party_id': 'party:52',
#  'party_list_position': '',
#  'party_lists_in_use': 'False',
#  'party_name': 'Conservative and Unionist Party',
#  'party_ppc_page_url': '',
#  'post_id': 'DIW:E05005367',
#  'post_label': 'Knowsley',
#  'proxy_image_url_template': '',
#  'theyworkforyou_url': '',
#  'twitter_user_id': '',
#  'twitter_username': '',
#  'wikipedia_url': ''}

# %%
# LINK CANDIDATE DATA TO BALLOTS

matchedCandidates = []

for electionType in ballots:
    for orgId in ballots[electionType]:
        for ballotId in ballots[electionType][orgId]['ballots']:  
            ballot = ballots[electionType][orgId]['ballots'][ballotId]
            ballot['candidates'] = {}
            orgCandidates = candidates[orgId]
            for candidateId in orgCandidates:
                if ballot['division_name'] == orgCandidates[candidateId]['post_label']:
                    ballot['candidates'][candidateId] = orgCandidates[candidateId]
                    matchedCandidates.append(candidateId)

# %%
# OUTPUT TO JSON FILE

with open('upcoming_elections.json', 'w') as outfile:
    json.dump(ballots, outfile)

# %%
# PRINT OUT A LIST OF ELECTIONS

for electionType in ballots:
    
    print('')
    print(electionTypes[electionType])
    
    for orgId in ballots[electionType]:

        # Our master list of organistions is keyed with the org slug, which we have saved in our ballot record
        # So use this to lookup the election name from the organisation master data
        print('')
        print(organisations[ballots[electionType][orgId]['organisation_slug']]['election_name'])

        for ballotId in ballots[electionType][orgId]['ballots']:   
            
            ballot = ballots[electionType][orgId]['ballots'][ballotId]
            
            seatsCount = str(ballot['seats_total'])
            plural = ''
            if  ballot['seats_total'] is None:
                seatsCount = '[unknown number of]'
                plural = 's'
            elif int(ballot['seats_total']) > 1:
                plural = 's'

            print('  - ' + 
                  ballot['election_type_name'] + ' for ' + 
                  seatsCount + ' ' + 
                  ballot['elected_role'] + plural + ' in ' + 
                  ballot['organisation_name'] + "'s " + 
                  ballot['division_name'] + ' division, on ' +  
                  str(ballot['poll_open_date']))
            
            print('')
            if len(ballot['candidates']) == 0:
                print('No candidates in data yet')
                
            for candidateId in ballot['candidates']:
                
                can = ballot['candidates'][candidateId]
                gender = 'UNKNOWN'
                
                if can['gender'] is not None and can['gender'] != '':
                    gender = can['gender']
                
                print('    - ' + can['name'] + ' | ' + 
                      ' Gender: ' + gender + ' | ' + 
                      '@' + can['twitter_username'])
# Out:
# ''
# 'Local elections'
# ''
# 'Bury local election'
# ("  - Local elections for [unknown number of] Local Councillors in Bury's East "
#  'division, on 2018-08-16')
# ''
# 'No candidates in data yet'
# ''
# 'City of London local election'
# ('  - Local elections for [unknown number of] Local Councillors in City of '
#  "London's Bread Street division, on 2018-08-30")
# ''
# 'No candidates in data yet'
# ''
# 'Cornwall local election'
# ("  - Local elections for [unknown number of] Local Councillors in Cornwall's "
#  'Bude division, on 2018-08-23')
# ''
# 'No candidates in data yet'
# ''
# 'Cornwall local election'
# ("  - Local elections for [unknown number of] Local Councillors in Cornwall's "
#  'Newquay Treviglas division, on 2018-08-09')
# ''
# 'No candidates in data yet'
# ''
# 'East Devon local election'
# ('  - Local elections for [unknown number of] Local Councillors in East '
#  "Devon's Ottery St Mary Rural division, on 2018-09-20")
# ''
# 'No candidates in data yet'
# ''
# 'East Hertfordshire local election'
# ('  - Local elections for [unknown number of] Local Councillors in East '
#  "Hertfordshire's Watton-at-Stone division, on 2018-08-23")
# ''
# 'No candidates in data yet'
# ''
# 'Fife local election'
# ("  - Local elections for 4 Local Councillors in Fife's Inverkeithing and "
#  'Dalgety Bay division, on 2018-09-06')
# ''
# 'No candidates in data yet'
# ''
# 'Fylde local election'
# ("  - Local elections for [unknown number of] Local Councillors in Fylde's "
#  'Ansdell division, on 2018-08-02')
# ''
# '    - Chris Dixon |  Gender: UNKNOWN | @'
# '    - Gareth Stuart Nash |  Gender: UNKNOWN | @'
# ''
# "King's Lynn and West Norfolk local election"
# ("  - Local elections for [unknown number of] Local Councillors in King's Lynn "
#  "and West Norfolk's Snettisham division, on 2018-08-02")
# ''
# 'No candidates in data yet'
# ''
# 'Merthyr Tydfil local election'
# ('  - Local elections for [unknown number of] Local Councillors in Merthyr '
#  "Tydfil's Gurnos division, on 2018-07-26")
# ''
# '    - Jeremy Islwyn Trevor Davies |  Gender: UNKNOWN | @'
# '    - Laurel Elizabeth Ellis |  Gender: UNKNOWN | @'
# '    - Allyn Hooper |  Gender: male | @WrAllynHooper'
# '    - Dillan Singh |  Gender: UNKNOWN | @'
# ''
# 'New Forest local election'
# ('  - Local elections for [unknown number of] Local Councillors in New '
#  "Forest's Fawley, Blackfield and Langley division, on 2018-07-26")
# ''
# '    - Craig Fletcher |  Gender: UNKNOWN | @'
# '    - Merv Langdale |  Gender: UNKNOWN | @'
# ''
# 'North East Lincolnshire local election'
# ('  - Local elections for [unknown number of] Local Councillors in North East '
#  "Lincolnshire's Freshney division, on 2018-07-26")
# ''
# 'No candidates in data yet'
# ''
# 'North Warwickshire local election'
# ('  - Local elections for [unknown number of] Local Councillors in North '
#  "Warwickshire's Newton Regis and Warton division, on 2018-08-23")
# ''
# 'No candidates in data yet'
# ''
# 'Police and Crime Commissioner for North Yorkshire Police'
# ('  - Local elections for [unknown number of] Local Councillors in North '
#  "Yorkshire's Knaresborough division, on 2018-08-16")
# ''
# 'No candidates in data yet'
# ''
# 'Peterborough local election'
# ('  - Local elections for [unknown number of] Local Councillors in '
#  "Peterborough's Orton Longueville division, on 2018-08-02")
# ''
# 'No candidates in data yet'
# ''
# 'Plymouth local election'
# ("  - Local elections for [unknown number of] Local Councillors in Plymouth's "
#  'Stoke division, on 2018-07-26')
# ''
# '    - Connor Clarke |  Gender: UNKNOWN | @'
# '    - Jemima Mary Laing |  Gender: Female | @jemimalaing'
# '    - Iuliu Popescu |  Gender: male | @Active4Plymouth'
# '    - Kathy Watkin |  Gender: female | @kathy4stoke1'
# ''
# 'Redditch local election'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Abbey division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Astwood Bank and Feckenham division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Batchley & Brockhill division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Church Hill division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Crabbs Cross division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Greenlands division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Headless Cross and Oakenshaw division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Matchborough division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'West division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ("  - Local elections for [unknown number of] Local Councillors in Redditch's "
#  'Winyates division, on 2019-05-02')
# ''
# 'No candidates in data yet'
# ''
# 'Rushcliffe local election'
# ('  - Local elections for [unknown number of] Local Councillors in '
#  "Rushcliffe's Gotham division, on 2018-08-23")
# ''
# 'No candidates in data yet'
# ''
# 'Thanet local election'
# ("  - Local elections for [unknown number of] Local Councillors in Thanet's "
#  'Birchington South division, on 2018-07-26')
# ''
# 'No candidates in data yet'
# ''
# 'Torridge local election'
# ("  - Local elections for [unknown number of] Local Councillors in Torridge's "
#  'Hartland and Bradworthy division, on 2018-07-26')
# ''
# 'No candidates in data yet'
# ''
# 'West Lancashire local election'
# ('  - Local elections for [unknown number of] Local Councillors in West '
#  "Lancashire's Knowsley division, on 2018-07-26")
# ''
# '    - Gareth Dowling |  Gender: male | @garethdowling'
# '    - Kate Mitchell |  Gender: female | @'
# '    - Jeffrey Vernon |  Gender: UNKNOWN | @'
